# %%
# !pip freeze | grep scikit-learn
# Out:
# scikit-learn==1.5.0

# %%
# !python -V
# Out:
# Python 3.10.13

# %%
import pickle
import pandas as pd

# %%
with open('model.bin', 'rb') as f_in:
    dv, model = pickle.load(f_in)

# %%
categorical = ['PULocationID', 'DOLocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
df = read_data('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')

# %%
dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)

# %% [markdown]
# ## Q1

# %%
y_pred.std()
# Out:
# 6.247488852238703

# %% [markdown]
# ## Q2

# %%
year = 2023
month = 3

# %%
df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1         2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2         1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3         1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4         2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           0.00         1.0                  N          238           42
# 1          12.40         1.0                  N          138          231
# 2           3.30         1.0                  N          140          186
# 3           2.90         1.0                  N          140           43
# 4           1.23         1.0                  N           79          137
#
#    payment_type  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2  ...    1.0      0.5        0.00           0.0
# 1             1  ...    6.0      0.5       12.54           0.0
# 2             1  ...    3.5      0.5        4.65           0.0
# 3             1  ...    3.5      0.5        4.10           0.0
# 4             1  ...    1.0      0.5        2.44           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         11.10                   0.0         0.00
# 1                    1.0         76.49                   2.5         1.25
# 2                    1.0         28.05                   2.5         0.00
# 3                    1.0         24.70                   2.5         0.00
# 4                    1.0         14.64                   2.5         0.00
#
#     duration    ride_id
# 0  10.000000  2023/03_0
# 1  31.083333  2023/03_1
# 2  14.366667  2023/03_2
# 3  11.466667  2023/03_3
# 4   3.033333  2023/03_4
#
# [5 rows x 21 columns]

# %%
output_file = 'df_result.csv'

# %%
df_result = df[['ride_id']].copy()
df_result['Result'] = y_pred
df_result.head()
# Out:
#      ride_id     Result
# 0  2023/03_0  16.245906
# 1  2023/03_1  26.134796
# 2  2023/03_2  11.884264
# 3  2023/03_3  11.997720
# 4  2023/03_4  10.234486

# %%
df_result.to_parquet(
    output_file,
    engine='pyarrow',
    compression=None,
    index=False
)

# %%
# !stat df_result.csv
# Out:
#   File: df_result.csv
#   Size: 68641704  	Blocks: 134080     IO Block: 4096   regular file
# Device: 703h/1795d	Inode: 1573140     Links: 1
# Access: (0666/-rw-rw-rw-)  Uid: ( 1000/codespace)   Gid: ( 1000/codespace)
# Access: 2024-06-10 09:10:45.683080197 +0000
# Modify: 2024-06-10 09:10:45.947080203 +0000
# Change: 2024-06-10 09:10:45.947080203 +0000
#  Birth: -

# %% [markdown]
# ## Q3

# %%
# !jupyter nbconvert --to script starter.ipynb
# Out:
# [NbConvertApp] Converting notebook starter.ipynb to script
# [NbConvertApp] Writing 1535 bytes to starter.py

# %% [markdown]
# ## Q4

# %% [markdown]
# ## Q5

# %%
# !python starter.py 2023 04
# Out:
# 14.292282936862449

# %% [markdown]
# ## Q6

# %%
# !docker build -t homework4:v1 .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.4s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.3s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.5s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.5s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.7s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.8s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.8s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.0s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.9s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.1s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.1s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.3s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.4s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.4s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.6s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.5s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.7s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 1.8s (6/12)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
# [+] Building 1.9s (11/12)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.1s
# [+] Building 2.0s (12/12)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
# [+] Building 2.1s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 2.3s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 2.4s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 2.6s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 2.7s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 2.9s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 3.0s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 3.2s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 3.3s (12/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 3.4s (13/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.3s
#  => => writing image sha256:58caca69f28e2328ef4e51470e5cbf33d88532440fdc0  0.0s
#  => => naming to docker.io/library/homework4:v1                            0.0s
# [+] Building 3.6s (13/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.3s
#  => => writing image sha256:58caca69f28e2328ef4e51470e5cbf33d88532440fdc0  0.0s
#  => => naming to docker.io/library/homework4:v1                            0.0s
# [+] Building 3.7s (13/13)                                        docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.3s
#  => => writing image sha256:58caca69f28e2328ef4e51470e5cbf33d88532440fdc0  0.0s
#  => => naming to docker.io/library/homework4:v1                            0.0s
# [+] Building 3.8s (13/13) FINISHED                               docker:default
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  1.6s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 1.21kB                                        0.0s
#  => CACHED [2/7] RUN pip install -U pip                                    0.0s
#  => CACHED [3/7] RUN pip install pipenv                                    0.0s
#  => CACHED [4/7] WORKDIR /app                                              0.0s
#  => CACHED [5/7] COPY [Pipfile, Pipfile.lock, ./]                          0.0s
#  => CACHED [6/7] RUN pipenv install --system --deploy                      0.0s
#  => [7/7] COPY [starter.py, ./]                                            0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.3s
#  => => writing image sha256:58caca69f28e2328ef4e51470e5cbf33d88532440fdc0  0.0s
#  => => naming to docker.io/library/homework4:v1                            0.0s

# %%
# !docker run homework4:v1
# Out:
# 0.19174419265916945
